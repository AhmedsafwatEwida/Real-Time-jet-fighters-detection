# %%
import warnings
import numpy as np
import argparse
import time
import cv2
import os
warnings.filterwarnings("ignore")

# %%
# Create DarkNet Environment
def prepare_environment():
    os.environ['PATH'] += ':/usr/local/cuda/bin'
    # !rm -fr darknet
    # !git clone https://github.com/AlexeyAB/darknet/
    # !apt install gcc-5 g++-5 -y
    # !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc 
    # !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
    # %cd darknet
    # !sed -i 's/GPU=0/GPU=1/g' Makefile
    # !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
    # !make
    # get yolov3 weights
    #!wget https://pjreddie.com/media/files/darknet53.conv.74.weights
    # !chmod a+x ./darknet
    # !apt install ffmpeg libopencv-dev libgtk-3-dev python-numpy python3-numpy libdc1394-22 libdc1394-22-dev libjpeg-dev libtiff5-dev libavcodec-dev libavformat-dev libswscale-dev libxine2-dev libgstreamer1.0-dev libgstreamer-plugins-base1.0-dev libv4l-dev libtbb-dev qtbase5-dev libfaac-dev libmp3lame-dev libopencore-amrnb-dev libopencore-amrwb-dev libtheora-dev libvorbis-dev libxvidcore-dev x264 v4l-utils unzip
    status='Completed'
    return status
prepare_environment()
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 13627, done.
# remote: Total 13627 (delta 0), reused 0 (delta 0), pack-reused 13627
# Receiving objects: 100% (13627/13627), 12.24 MiB | 24.20 MiB/s, done.
# Resolving deltas: 100% (9296/9296), done.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0 libstdc++-5-dev
# Suggested packages:
#   gcc-5-locales g++-5-multilib gcc-5-doc libstdc++6-5-dbg gcc-5-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan2-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx0-dbg
#   libquadmath0-dbg libstdc++-5-doc
# The following NEW packages will be installed:
#   cpp-5 g++-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# 0 upgraded, 9 newly installed, 0 to remove and 32 not upgraded.
# Need to get 29.1 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5-base amd64 5.5.0-12ubuntu1 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libisl15 amd64 0.18-4 [548 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 cpp-5 amd64 5.5.0-12ubuntu1 [7,785 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libasan2 amd64 5.5.0-12ubuntu1 [264 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmpx0 amd64 5.5.0-12ubuntu1 [9,888 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgcc-5-dev amd64 5.5.0-12ubuntu1 [2,224 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5 amd64 5.5.0-12ubuntu1 [8,357 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libstdc++-5-dev amd64 5.5.0-12ubuntu1 [1,415 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 g++-5 amd64 5.5.0-12ubuntu1 [8,450 kB]
# Fetched 29.1 MB in 3s (8,509 kB/s)
# Selecting previously unselected package gcc-5-base:amd64.
# (Reading database ... 144467 files and directories currently installed.)
# Preparing to unpack .../0-gcc-5-base_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking gcc-5-base:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libisl15:amd64.
# Preparing to unpack .../1-libisl15_0.18-4_amd64.deb ...
# Unpacking libisl15:amd64 (0.18-4) ...
# Selecting previously unselected package cpp-5.
# Preparing to unpack .../2-cpp-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking cpp-5 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libasan2:amd64.
# Preparing to unpack .../3-libasan2_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libasan2:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libmpx0:amd64.
# Preparing to unpack .../4-libmpx0_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libmpx0:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libgcc-5-dev:amd64.
# Preparing to unpack .../5-libgcc-5-dev_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libgcc-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package gcc-5.
# Preparing to unpack .../6-gcc-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking gcc-5 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libstdc++-5-dev:amd64.
# Preparing to unpack .../7-libstdc++-5-dev_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libstdc++-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package g++-5.
# Preparing to unpack .../8-g++-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking g++-5 (5.5.0-12ubuntu1) ...
# Setting up libisl15:amd64 (0.18-4) ...
# Setting up gcc-5-base:amd64 (5.5.0-12ubuntu1) ...
# Setting up libmpx0:amd64 (5.5.0-12ubuntu1) ...
# Setting up libasan2:amd64 (5.5.0-12ubuntu1) ...
# Setting up libgcc-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Setting up cpp-5 (5.5.0-12ubuntu1) ...
# Setting up libstdc++-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Setting up gcc-5 (5.5.0-12ubuntu1) ...
# Setting up g++-5 (5.5.0-12ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:910:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1391:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^
# ./src/image_opencv.cpp:1367:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#      int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#          ^
# ./src/image_opencv.cpp:1371:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#      int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#          ^
# ./src/image_opencv.cpp:1375:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#      int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#          ^
# ./src/image_opencv.cpp:1378:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#      int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#          ^
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/http_stream.cpp -o obj/http_stream.o
# In file included from ./src/http_stream.cpp:580:0:
# ./src/httplib.h:129:0: warning: "INVALID_SOCKET" redefined
#  #define INVALID_SOCKET (-1)
#  ^
# ./src/http_stream.cpp:73:0: note: this is the location of the previous definition
#  #define INVALID_SOCKET -1
#  ^
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:249:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:507:113: warning: format ‘%zu’ expects argument of type ‘size_t’, but argument 3 has type ‘int’ [-Wformat=]
#                  sprintf(head, "--mjpegstream\r\nContent-Type: image/jpeg\r\nContent-Length: %zu\r\n\r\n", outlen);
#                                                                                                                  ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2038:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^
# ./src/gemm.c:2037:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:276:16: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                 ^
# ./src/dark_cuda.c:276:16: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
# ./src/dark_cuda.c:276:16: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
# ./src/dark_cuda.c:286:24: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                         ^
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:307:20: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                     ^
# ./src/dark_cuda.c:322:20: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                     ^
# ./src/dark_cuda.c:328:20: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                     ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1204:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:77:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#      switch(a){
#      ^
# ./src/activations.c:77:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:287:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^
# ./src/activations.c:287:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1243:24: warning: unused variable ‘x’ [-Wunused-variable]
#                  int k, x, y;
#                         ^
# ./src/data.c:1044:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#      float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#                                            ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:610:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/connected_layer.c -o obj/connected_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1591:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#      switch(iou_kind) {
#      ^
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘print_cocos’:
# ./src/detector.c:455:29: warning: format not a string literal and no format arguments [-Wformat-security]
#                  fprintf(fp, buff);
#                              ^
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:548:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:661:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^
# ./src/detector.c:659:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1280:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^
# ./src/detector.c:1279:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1796:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#              float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#                    ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:198:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#      if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#                                                                     ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:138:9: warning: unused variable ‘count’ [-Wunused-variable]
#      int count = 0;
#          ^
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:831:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1261:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                                  ^
# ./src/classifier.c:1261:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                      ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:100:16: warning: unused variable ‘prediction’ [-Wunused-variable]
#          float *prediction = network_predict(net, X);
#                 ^
# ./src/demo.c:98:15: warning: unused variable ‘l’ [-Wunused-variable]
#          layer l = net.layers[net.n - 1];
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:58:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#      int old_h = l->h;
#          ^
# ./src/region_layer.c:57:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#      int old_w = l->w;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:62:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c:69:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:96:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c:105:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# ./src/gaussian_yolo_layer.c: In function ‘make_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:71:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/gaussian_yolo_layer.c:78:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:110:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/gaussian_yolo_layer.c:119:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.28-1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../31-libgstreamer-plugins-base1.0-0_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../32-libgstreamer-gl1.0-0_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package gir1.2-gst-plugins-base-1.0:amd64.
# Preparing to unpack .../33-gir1.2-gst-plugins-base-1.0_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking gir1.2-gst-plugins-base-1.0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../34-libpangoxft-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../35-gir1.2-pango-1.0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-gtk-3.0:amd64.
# Preparing to unpack .../36-gir1.2-gtk-3.0_3.22.30-1ubuntu4_amd64.deb ...
# Unpacking gir1.2-gtk-3.0:amd64 (3.22.30-1ubuntu4) ...
# Selecting previously unselected package libgraphene-1.0-0:amd64.
# Preparing to unpack .../37-libgraphene-1.0-0_1.8.0-1_amd64.deb ...
# Unpacking libgraphene-1.0-0:amd64 (1.8.0-1) ...
# Selecting previously unselected package gstreamer1.0-gl:amd64.
# Preparing to unpack .../38-gstreamer1.0-gl_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking gstreamer1.0-gl:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../39-libcdparanoia0_3.10.2+debian-13_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../40-libvisual-0.4-0_0.4.0-11_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-11) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../41-gstreamer1.0-plugins-base_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../42-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../43-libdbus-1-dev_1.12.2-1ubuntu1.1_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.2-1ubuntu1.1) ...
# Selecting previously unselected package x11proto-record-dev.
# Preparing to unpack .../44-x11proto-record-dev_2018.4-4_all.deb ...
# Unpacking x11proto-record-dev (2018.4-4) ...
# Selecting previously unselected package libxtst-dev:amd64.
# Preparing to unpack .../45-libxtst-dev_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst-dev:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libatspi2.0-dev:amd64.
# Preparing to unpack .../46-libatspi2.0-dev_2.28.0-1_amd64.deb ...
# Unpacking libatspi2.0-dev:amd64 (2.28.0-1) ...
# Selecting previously unselected package libatk-bridge2.0-dev:amd64.
# Preparing to unpack .../47-libatk-bridge2.0-dev_2.26.2-1_amd64.deb ...
# Unpacking libatk-bridge2.0-dev:amd64 (2.26.2-1) ...
# Selecting previously unselected package libatk1.0-dev:amd64.
# Preparing to unpack .../48-libatk1.0-dev_2.28.1-1_amd64.deb ...
# Unpacking libatk1.0-dev:amd64 (2.28.1-1) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../49-libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../50-libpixman-1-dev_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../51-libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../52-libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libepoxy-dev:amd64.
# Preparing to unpack .../53-libepoxy-dev_1.4.3-1_amd64.deb ...
# Unpacking libepoxy-dev:amd64 (1.4.3-1) ...
# Selecting previously unselected package libfaac0:amd64.
# Preparing to unpack .../54-libfaac0_1.29.7.7-1_amd64.deb ...
# Unpacking libfaac0:amd64 (1.29.7.7-1) ...
# Selecting previously unselected package libfaac-dev:amd64.
# Preparing to unpack .../55-libfaac-dev_1.29.7.7-1_amd64.deb ...
# Unpacking libfaac-dev:amd64 (1.29.7.7-1) ...
# Selecting previously unselected package libffms2-4:amd64.
# Preparing to unpack .../56-libffms2-4_2.23-2_amd64.deb ...
# Unpacking libffms2-4:amd64 (2.23-2) ...
# Selecting previously unselected package libgdk-pixbuf2.0-dev.
# Preparing to unpack .../57-libgdk-pixbuf2.0-dev_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Selecting previously unselected package libgpac4:amd64.
# Preparing to unpack .../58-libgpac4_0.5.2-426-gc5ad4e4+dfsg5-3ubuntu0.1_amd64.deb ...
# Unpacking libgpac4:amd64 (0.5.2-426-gc5ad4e4+dfsg5-3ubuntu0.1) ...
# Selecting previously unselected package libgstreamer1.0-dev:amd64.
# Preparing to unpack .../59-libgstreamer1.0-dev_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Adding 'diversion of /usr/bin/dh_gstscancodecs to /usr/bin/dh_gstscancodecs-gst0.10 by libgstreamer1.0-dev'
# Adding 'diversion of /usr/share/man/man1/dh_gstscancodecs.1.gz to /usr/share/man/man1/dh_gstscancodecs.1.gz-gst0.10 by libgstreamer1.0-dev'
# Unpacking libgstreamer1.0-dev:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package liborc-0.4-dev-bin.
# Preparing to unpack .../60-liborc-0.4-dev-bin_1%3a0.4.28-1_amd64.deb ...
# Unpacking liborc-0.4-dev-bin (1:0.4.28-1) ...
# Selecting previously unselected package liborc-0.4-dev.
# Preparing to unpack .../61-liborc-0.4-dev_1%3a0.4.28-1_amd64.deb ...
# Unpacking liborc-0.4-dev (1:0.4.28-1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-dev:amd64.
# Preparing to unpack .../62-libgstreamer-plugins-base1.0-dev_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-dev:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libpango1.0-dev.
# Preparing to unpack .../63-libpango1.0-dev_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../64-x11proto-xinerama-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xinerama-dev (2018.4-4) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../65-libxinerama-dev_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../66-x11proto-randr-dev_2018.4-4_all.deb ...
# Unpacking x11proto-randr-dev (2018.4-4) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../67-libxrandr-dev_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.1-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../68-libxcursor-dev_1%3a1.1.15-1_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.1.15-1) ...
# Selecting previously unselected package x11proto-composite-dev.
# Preparing to unpack .../69-x11proto-composite-dev_1%3a2018.4-4_all.deb ...
# Unpacking x11proto-composite-dev (1:2018.4-4) ...
# Selecting previously unselected package libxcomposite-dev:amd64.
# Preparing to unpack .../70-libxcomposite-dev_1%3a0.4.4-2_amd64.deb ...
# Unpacking libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Selecting previously unselected package wayland-protocols.
# Preparing to unpack .../71-wayland-protocols_1.13-1_all.deb ...
# Unpacking wayland-protocols (1.13-1) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../72-libxkbcommon-dev_0.8.2-1~ubuntu18.04.1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Selecting previously unselected package libgtk-3-dev:amd64.
# Preparing to unpack .../73-libgtk-3-dev_3.22.30-1ubuntu4_amd64.deb ...
# Unpacking libgtk-3-dev:amd64 (3.22.30-1ubuntu4) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../74-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../75-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Selecting previously unselected package libmp3lame-dev:amd64.
# Preparing to unpack .../76-libmp3lame-dev_3.100-2_amd64.deb ...
# Unpacking libmp3lame-dev:amd64 (3.100-2) ...
# Selecting previously unselected package libopencore-amrnb-dev:amd64.
# Preparing to unpack .../77-libopencore-amrnb-dev_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrnb-dev:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libopencore-amrwb-dev:amd64.
# Preparing to unpack .../78-libopencore-amrwb-dev_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrwb-dev:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libtheora-dev:amd64.
# Preparing to unpack .../79-libtheora-dev_1.1.1+dfsg.1-14_amd64.deb ...
# Unpacking libtheora-dev:amd64 (1.1.1+dfsg.1-14) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../80-libv4lconvert0_1.14.2-1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.14.2-1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../81-libv4l-0_1.14.2-1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.14.2-1) ...
# Selecting previously unselected package libv4l2rds0:amd64.
# Preparing to unpack .../82-libv4l2rds0_1.14.2-1_amd64.deb ...
# Unpacking libv4l2rds0:amd64 (1.14.2-1) ...
# Selecting previously unselected package libv4l-dev:amd64.
# Preparing to unpack .../83-libv4l-dev_1.14.2-1_amd64.deb ...
# Unpacking libv4l-dev:amd64 (1.14.2-1) ...
# Selecting previously unselected package libxine2-bin.
# Preparing to unpack .../84-libxine2-bin_1.2.8-2build2_amd64.deb ...
# Unpacking libxine2-bin (1.2.8-2build2) ...
# Selecting previously unselected package libxine2-dev.
# Preparing to unpack .../85-libxine2-dev_1.2.8-2build2_amd64.deb ...
# Unpacking libxine2-dev (1.2.8-2build2) ...
# Selecting previously unselected package libxvidcore-dev:amd64.
# Preparing to unpack .../86-libxvidcore-dev_2%3a1.3.5-1_amd64.deb ...
# Unpacking libxvidcore-dev:amd64 (2:1.3.5-1) ...
# Selecting previously unselected package v4l-utils.
# Preparing to unpack .../87-v4l-utils_1.14.2-1_amd64.deb ...
# Unpacking v4l-utils (1.14.2-1) ...
# Selecting previously unselected package x264.
# Preparing to unpack .../88-x264_2%3a0.152.2854+gite9a5903-2_amd64.deb ...
# Unpacking x264 (2:0.152.2854+gite9a5903-2) ...
# Setting up libdbus-1-dev:amd64 (1.12.2-1ubuntu1.1) ...
# Setting up libfaac0:amd64 (1.29.7.7-1) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Setting up libv4l2rds0:amd64 (1.14.2-1) ...
# Setting up libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Setting up libpam-cap:amd64 (1:2.25-1.2) ...
# Setting up libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up libtheora-dev:amd64 (1.1.1+dfsg.1-14) ...
# Setting up libcap2-bin (1:2.25-1.2) ...
# Setting up gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Setting up libv4lconvert0:amd64 (1.14.2-1) ...
# Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Setting up libatk1.0-dev:amd64 (2.28.1-1) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.3) ...
# Setting up libffms2-4:amd64 (2.23-2) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Setting up x11proto-record-dev (2018.4-4) ...
# Setting up libxine2-bin (1.2.8-2build2) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libxtst-dev:amd64 (2:1.2.3-1) ...
# Setting up liborc-0.4-dev-bin (1:0.4.28-1) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up libxvidcore-dev:amd64 (2:1.3.5-1) ...
# Setting up x11proto-xinerama-dev (2018.4-4) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# Setting up libfaac-dev:amd64 (1.29.7.7-1) ...
# Setting up x11proto-randr-dev (2018.4-4) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Setting up libxine2-dev (1.2.8-2build2) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-11) ...
# Setting up libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Setting up libgraphene-1.0-0:amd64 (1.8.0-1) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.28-1) ...
# Setting up libmp3lame-dev:amd64 (3.100-2) ...
# Setting up libgpac4:amd64 (0.5.2-426-gc5ad4e4+dfsg5-3ubuntu0.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Setting up wayland-protocols (1.13-1) ...
# Setting up x11proto-composite-dev (1:2018.4-4) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.3) ...
# Setting up libepoxy-dev:amd64 (1.4.3-1) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up gir1.2-atspi-2.0:amd64 (2.28.0-1) ...
# Setting up libgstreamer1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setcap worked! gst-ptp-helper is not suid!
# Setting up gir1.2-gtk-3.0:amd64 (3.22.30-1ubuntu4) ...
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up libv4l-0:amd64 (1.14.2-1) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Setting up x264 (2:0.152.2854+gite9a5903-2) ...
# Setting up v4l-utils (1.14.2-1) ...
# Setting up libopencore-amrnb-dev:amd64 (0.1.3-2.1) ...
# Setting up autoconf (2.69-11) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up libatspi2.0-dev:amd64 (2.28.0-1) ...
# Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up libatk-bridge2.0-dev:amd64 (2.26.2-1) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up liborc-0.4-dev (1:0.4.28-1) ...
# Setting up libv4l-dev:amd64 (1.14.2-1) ...
# Setting up libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Setting up libopencore-amrwb-dev:amd64 (0.1.3-2.1) ...
# Setting up gir1.2-gstreamer-1.0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up libtool (2.4.6-2) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up libgtk-3-dev:amd64 (3.22.30-1ubuntu4) ...
# Setting up po-debconf (1.0.20) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up gstreamer1.0-gl:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up gir1.2-gst-plugins-base-1.0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up libgstreamer1.0-dev:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up libgstreamer-plugins-base1.0-dev:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up dh-autoreconf (17) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libglib2.0-0:amd64 (2.56.4-0ubuntu0.18.04.6) ...
# 'Completed'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
os.listdir('/content/drive/My Drive/darknet/YOLO_Custom')
# Out:
# ['obj.names',
#  'images',
#  'yolov3-tiny_obj_test.cfg',
#  'yolov3-tiny_obj_train.cfg',
#  'obj.data',
#  'test.txt',
#  'train.txt']

# %%
# !wget --header="Host: pjreddie.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://github.com/AlexeyAB/darknet" --header="Cookie: __utma=134107727.1364647705.1589636782.1589689587.1589901067.3; __utmz=134107727.1589901067.3.3.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)" --header="Connection: keep-alive" "https://pjreddie.com/media/files/yolov3-tiny.weights" -c -O 'yolov3-tiny.weights'
# Out:
# --2020-06-06 15:32:39--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M   422KB/s    in 66s
#
# 2020-06-06 15:33:47 (523 KB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]

# %%
# !./darknet partial cfg/yolov3-tiny.cfg yolov3-tiny.weights yolov3-tiny.conv.15 15
# Out:
#  CUDA-version: 10010 (10010), GPU count: 1
#  OpenCV version: 3.2.0
#  GPU isn't used
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
#    8 conv    256       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 256 0.399 BF
#    9 max                2x 2/ 2     26 x  26 x 256 ->   13 x  13 x 256 0.000 BF
#   10 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   11 max                2x 2/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.000 BF
#   12 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   13 conv    256       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 256 0.089 BF
#   14 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   15 conv    255       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 255 0.044 BF
#   16 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   17 route  13 		                           ->   13 x  13 x 256
#   18 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   19 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   20 route  19 8 	                           ->   26 x  26 x 384
#   21 conv    256       3 x 3/ 1     26 x  26 x 384 ->   26 x  26 x 256 1.196 BF
#   22 conv    255       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 255 0.088 BF
#   23 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 5.571
# avg_outputs = 341534
# Loading weights from yolov3-tiny.weights...
#  seen 64, trained: 32013 K-images (500 Kilo-batches_64)
# Done! Loaded 15 layers from weights-file
# Saving weights to yolov3-tiny.conv.15

# %%
# Copy fils from Google Drive to the VM local filesystem
# !cp -r "/content/drive/My Drive/darknet/YOLO_Custom" /content/darknet/YOLO_Custom

# %%
# !./darknet detector train "/content/darknet/YOLO_Custom/obj.data" "/content/darknet/YOLO_Custom/yolov3-tiny_obj_train.cfg" "/content/darknet/yolov3-tiny.conv.15" "train.log" -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000012, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000694, iou_loss = 0.000000, total_loss = 0.000694
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.809698, GIOU: 0.809698), Class: 0.999599, Obj: 0.082839, No Obj: 0.000306, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.213916, iou_loss = 0.048677, total_loss = 0.262593
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.607612, GIOU: 0.579578), Class: 0.989232, Obj: 0.758922, No Obj: 0.000100, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.043612, iou_loss = 0.106557, total_loss = 0.150169
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.738881, GIOU: 0.709290), Class: 0.997261, Obj: 0.304495, No Obj: 0.000956, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.288135, iou_loss = 0.078896, total_loss = 0.367032
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000003, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
#
#  5179: 0.215643, 0.172495 avg loss, 0.000010 rate, 1.013358 seconds, 331456 images, 14069.980413 hours left
# Loaded: 0.000050 seconds
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.135.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (392).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5797).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.841218, GIOU: 0.836569), Class: 0.996502, Obj: 0.531437, No Obj: 0.001393, .5R: 1.000000, .75R: 1.000000, count: 3, class_loss = 0.290554, iou_loss = 0.112393, total_loss = 0.402947
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000012, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000339, iou_loss = 0.000000, total_loss = 0.000339
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1186).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (306).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.794206, GIOU: 0.781888), Class: 0.964246, Obj: 0.375799, No Obj: 0.001652, .5R: 1.000000, .75R: 0.333333, count: 3, class_loss = 0.418279, iou_loss = 0.138600, total_loss = 0.556879
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000006, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000054, iou_loss = 0.000000, total_loss = 0.000054
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (73).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5034).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.760768, GIOU: 0.760768), Class: 0.999999, Obj: 0.533460, No Obj: 0.000234, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.054807, iou_loss = 0.027223, total_loss = 0.082029
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000004, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000020, iou_loss = 0.000000, total_loss = 0.000020
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5839).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1262).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (150).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1696).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (3990).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000056, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000706, iou_loss = 0.000000, total_loss = 0.000706
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (330).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (249).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1267).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5858).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1159).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5838).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.688667, GIOU: 0.654907), Class: 0.999797, Obj: 0.004772, No Obj: 0.000035, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.247805, iou_loss = 0.059360, total_loss = 0.307166
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000003, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (238).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5803).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (284).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.912954, GIOU: 0.911990), Class: 0.999999, Obj: 0.972681, No Obj: 0.000606, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.029971, iou_loss = 0.009854, total_loss = 0.039825
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000005, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000011, iou_loss = 0.000000, total_loss = 0.000011
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (157).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.094.txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.765527, GIOU: 0.765527), Class: 0.998272, Obj: 0.047677, No Obj: 0.000393, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.278565, iou_loss = 0.028477, total_loss = 0.307042
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.797960, GIOU: 0.792708), Class: 0.996643, Obj: 0.691014, No Obj: 0.000107, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.024226, iou_loss = 0.023179, total_loss = 0.047405
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (81).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (112).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1095).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.836146, GIOU: 0.828187), Class: 0.999987, Obj: 0.890051, No Obj: 0.000761, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.007675, iou_loss = 0.027880, total_loss = 0.035555
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6047).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000010, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.001173, iou_loss = 0.000000, total_loss = 0.001173
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5873).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1216).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000127, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.006869, iou_loss = 0.000000, total_loss = 0.006869
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000010, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000759, iou_loss = 0.000000, total_loss = 0.000759
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (41).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1660).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.850835, GIOU: 0.849187), Class: 0.999566, Obj: 0.884471, No Obj: 0.000813, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.048608, iou_loss = 0.018786, total_loss = 0.067394
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000102, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.123701, iou_loss = 0.000000, total_loss = 0.123701
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (156).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192831.853.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (320).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (4001).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (253).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.850710, GIOU: 0.850680), Class: 0.999995, Obj: 0.751105, No Obj: 0.000519, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.015644, iou_loss = 0.035976, total_loss = 0.051620
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (297).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (168).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.108.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5808).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.569958, GIOU: 0.569958), Class: 0.994803, Obj: 0.273466, No Obj: 0.000441, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.184759, iou_loss = 0.162734, total_loss = 0.347493
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000009, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000099, iou_loss = 0.000000, total_loss = 0.000099
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (317).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000550, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.030261, iou_loss = 0.000000, total_loss = 0.030261
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000003, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.842866, GIOU: 0.842866), Class: 0.990778, Obj: 0.450317, No Obj: 0.000950, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.273326, iou_loss = 0.041637, total_loss = 0.314963
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000008, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000259, iou_loss = 0.000000, total_loss = 0.000259
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.865113, GIOU: 0.861207), Class: 0.999982, Obj: 0.416980, No Obj: 0.000751, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.216941, iou_loss = 0.123501, total_loss = 0.340442
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000005, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000096, iou_loss = 0.000000, total_loss = 0.000096
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.837954, GIOU: 0.833213), Class: 0.999497, Obj: 0.762283, No Obj: 0.000944, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.030939, iou_loss = 0.032577, total_loss = 0.063516
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.461237, GIOU: 0.429868), Class: 0.999959, Obj: 0.116268, No Obj: 0.000023, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.195749, iou_loss = 0.241025, total_loss = 0.436774
#
#  5180: 0.111419, 0.166387 avg loss, 0.000010 rate, 1.040990 seconds, 331520 images, 14070.076083 hours left
# Resizing, random_coef = 1.40
#
#  576 x 576
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (74).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (180).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images (44).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1222).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (68).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (199).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.333.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5786).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1659).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (58).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (351).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1116).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1207).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1715).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (265).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1135).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6032).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.127.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6068).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1652).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.111.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1201).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (111).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (3987).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (238).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192831.865.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (369).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (316).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5856).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (61).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1306).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (141).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1125).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (252).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (267).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (235).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1281).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (306).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (147).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6273).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6037).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.107.txt
#  try to allocate additional workspace_size = 47.78 MB
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1287).txt
#  CUDA allocate done!
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.138.txt
# Loaded: 0.019280 seconds
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192831.865.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6302).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.605001, GIOU: 0.560598), Class: 0.999724, Obj: 0.119333, No Obj: 0.000068, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.194481, iou_loss = 0.122737, total_loss = 0.317217
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (313).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1156).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1254).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.648183, GIOU: 0.603782), Class: 0.998960, Obj: 0.133236, No Obj: 0.000526, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.262285, iou_loss = 0.043283, total_loss = 0.305568
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (178).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000003, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6301).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5851).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6016).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1675).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000197, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.063317, iou_loss = 0.000000, total_loss = 0.063317
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000008, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000467, iou_loss = 0.000000, total_loss = 0.000467
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1702).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1297).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (74).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.839495, GIOU: 0.839495), Class: 0.922257, Obj: 0.007381, No Obj: 0.000358, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.282233, iou_loss = 0.013206, total_loss = 0.295439
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000031, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.011510, iou_loss = 0.000000, total_loss = 0.011510
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images (94).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (4003).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.761838, GIOU: 0.761838), Class: 0.999291, Obj: 0.077747, No Obj: 0.000171, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.226519, iou_loss = 0.066297, total_loss = 0.292816
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000023, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.010672, iou_loss = 0.000000, total_loss = 0.010672
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (186).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (285).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (206).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000130, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.002182, iou_loss = 0.000000, total_loss = 0.002182
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (155).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.816909, GIOU: 0.816654), Class: 0.987480, Obj: 0.054621, No Obj: 0.000319, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.456823, iou_loss = 0.073254, total_loss = 0.530078
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000029, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.033429, iou_loss = 0.000000, total_loss = 0.033429
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (329).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1124).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6042).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1249).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1230).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.738260, GIOU: 0.724351), Class: 0.999672, Obj: 0.112239, No Obj: 0.000720, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.498903, iou_loss = 0.178716, total_loss = 0.677619
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000005, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000065, iou_loss = 0.000000, total_loss = 0.000065
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.115.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.327.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1127).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1211).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.905649, GIOU: 0.903636), Class: 0.998547, Obj: 0.037846, No Obj: 0.000322, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.235864, iou_loss = 0.022426, total_loss = 0.258290
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000016, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.001824, iou_loss = 0.000000, total_loss = 0.001824
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.131.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6301).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (176).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (249).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.770058, GIOU: 0.759117), Class: 0.997466, Obj: 0.216093, No Obj: 0.000558, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.470611, iou_loss = 0.084379, total_loss = 0.554990
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192831.864.txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.765238, GIOU: 0.763046), Class: 0.999357, Obj: 0.404597, No Obj: 0.000659, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.289011, iou_loss = 0.105494, total_loss = 0.394505
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000003, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1228).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.742509, GIOU: 0.727540), Class: 0.997482, Obj: 0.393578, No Obj: 0.000591, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.276414, iou_loss = 0.122216, total_loss = 0.398630
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.778898, GIOU: 0.778899), Class: 0.998145, Obj: 0.223436, No Obj: 0.000017, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.150766, iou_loss = 0.043800, total_loss = 0.194565
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.768152, GIOU: 0.756446), Class: 0.999966, Obj: 0.199294, No Obj: 0.000532, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.357598, iou_loss = 0.094721, total_loss = 0.452319
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.923761, GIOU: 0.923067), Class: 0.999990, Obj: 0.945193, No Obj: 0.000370, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.008537, iou_loss = 0.005611, total_loss = 0.014148
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000294, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.090899, iou_loss = 0.000000, total_loss = 0.090899
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000019, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.010596, iou_loss = 0.000000, total_loss = 0.010596
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.730813, GIOU: 0.730813), Class: 0.158036, Obj: 0.032309, No Obj: 0.000335, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.668429, iou_loss = 0.052023, total_loss = 0.720452
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#
#  5181: 0.175988, 0.167347 avg loss, 0.000010 rate, 1.211062 seconds, 331584 images, 14074.010107 hours left
# Loaded: 0.000053 seconds
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192831.865.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.115.txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.790975, GIOU: 0.786569), Class: 0.998218, Obj: 0.087575, No Obj: 0.000642, .5R: 1.000000, .75R: 0.750000, count: 4, class_loss = 0.849981, iou_loss = 0.161617, total_loss = 1.011598
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000003, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (261).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.855484, GIOU: 0.855484), Class: 0.999696, Obj: 0.753523, No Obj: 0.000870, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.290669, iou_loss = 0.047279, total_loss = 0.337948
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000003, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000110, iou_loss = 0.000000, total_loss = 0.000110
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (313).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (31).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (304).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (277).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6076).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.702498, GIOU: 0.676958), Class: 0.988647, Obj: 0.282130, No Obj: 0.000440, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.420515, iou_loss = 0.323349, total_loss = 0.743864
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000012, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.001152, iou_loss = 0.000000, total_loss = 0.001152
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1307).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (480).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1700).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.325.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (306).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.777159, GIOU: 0.769233), Class: 0.999896, Obj: 0.713540, No Obj: 0.001111, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.142578, iou_loss = 0.085803, total_loss = 0.228381
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000010, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000693, iou_loss = 0.000000, total_loss = 0.000693
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (92).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5834).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6298).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (324).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.751483, GIOU: 0.736601), Class: 0.997746, Obj: 0.243945, No Obj: 0.000665, .5R: 1.000000, .75R: 0.250000, count: 4, class_loss = 0.819065, iou_loss = 0.173960, total_loss = 0.993024
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (311).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (331).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.633157, GIOU: 0.633157), Class: 0.990402, Obj: 0.085379, No Obj: 0.000271, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.233486, iou_loss = 0.105413, total_loss = 0.338899
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (3984).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1662).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (387).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (203).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000256, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.122713, iou_loss = 0.000000, total_loss = 0.122713
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.698299, GIOU: 0.673254), Class: 0.995851, Obj: 0.117973, No Obj: 0.000028, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.200103, iou_loss = 0.044897, total_loss = 0.245000
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (338).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (220).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (313).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5843).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.100.txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.788865, GIOU: 0.781247), Class: 0.995698, Obj: 0.005252, No Obj: 0.000136, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.254856, iou_loss = 0.076297, total_loss = 0.331154
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000020, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.012109, iou_loss = 0.000000, total_loss = 0.012109
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (304).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (263).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.838088, GIOU: 0.833449), Class: 0.999481, Obj: 0.929922, No Obj: 0.001047, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.074198, iou_loss = 0.034384, total_loss = 0.108582
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.091.txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.790983, GIOU: 0.777849), Class: 0.985670, Obj: 0.609861, No Obj: 0.000060, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.040540, iou_loss = 0.034278, total_loss = 0.074818
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (281).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6280).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5823).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.673680, GIOU: 0.659673), Class: 0.999112, Obj: 0.433001, No Obj: 0.001446, .5R: 1.000000, .75R: 0.000000, count: 3, class_loss = 0.508815, iou_loss = 0.243016, total_loss = 0.751831
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (91).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000004, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000040, iou_loss = 0.000000, total_loss = 0.000040
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1203).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (244).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1215).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.717242, GIOU: 0.694441), Class: 0.998294, Obj: 0.149426, No Obj: 0.000309, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.189138, iou_loss = 0.142706, total_loss = 0.331844
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000014, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.001133, iou_loss = 0.000000, total_loss = 0.001133
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6065).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (271).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000126, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.037774, iou_loss = 0.000000, total_loss = 0.037774
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000009, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000622, iou_loss = 0.000000, total_loss = 0.000622
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.959608, GIOU: 0.959608), Class: 0.999963, Obj: 0.604523, No Obj: 0.000395, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.041404, iou_loss = 0.001641, total_loss = 0.043045
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000015, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.001807, iou_loss = 0.000000, total_loss = 0.001807
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.682407, GIOU: 0.679241), Class: 0.998466, Obj: 0.333424, No Obj: 0.001040, .5R: 0.666667, .75R: 0.666667, count: 3, class_loss = 0.658170, iou_loss = 0.222224, total_loss = 0.880394
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000097, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.084397, iou_loss = 0.000000, total_loss = 0.084397
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.864101, GIOU: 0.860871), Class: 0.998299, Obj: 0.420156, No Obj: 0.000571, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.212153, iou_loss = 0.089267, total_loss = 0.301420
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.839911, GIOU: 0.839592), Class: 0.990964, Obj: 0.058084, No Obj: 0.000291, .5R: 1.000000, .75R: 1.000000, count: 3, class_loss = 0.674210, iou_loss = 0.114088, total_loss = 0.788298
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000005, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000474, iou_loss = 0.000000, total_loss = 0.000474
#
#  5182: 0.242910, 0.174904 avg loss, 0.000010 rate, 1.272389 seconds, 331648 images, 14104.204255 hours left
# Loaded: 0.000047 seconds
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (67).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (152).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (304).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1674).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (294).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (47).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.764203, GIOU: 0.756860), Class: 0.998494, Obj: 0.181371, No Obj: 0.000234, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.179143, iou_loss = 0.038641, total_loss = 0.217785
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000003, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1203).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (288).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.658990, GIOU: 0.623992), Class: 0.999826, Obj: 0.002046, No Obj: 0.000137, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.255737, iou_loss = 0.058574, total_loss = 0.314311
# ...
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1275).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.677951, GIOU: 0.658008), Class: 0.999764, Obj: 0.034887, No Obj: 0.000436, .5R: 1.000000, .75R: 0.000000, count: 2, class_loss = 0.480776, iou_loss = 0.160889, total_loss = 0.641666
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000020, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.001887, iou_loss = 0.000000, total_loss = 0.001887
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5780).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (280).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (94).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.886069, GIOU: 0.885143), Class: 0.998375, Obj: 0.517605, No Obj: 0.001977, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.156548, iou_loss = 0.040296, total_loss = 0.196844
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000003, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (334).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (52).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (295).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (74).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.110.txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000123, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.001842, iou_loss = 0.000000, total_loss = 0.001842
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.744907, GIOU: 0.740621), Class: 0.974514, Obj: 0.825973, No Obj: 0.000104, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.009106, iou_loss = 0.042917, total_loss = 0.052023
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6016).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (194).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1227).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (5797).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.784640, GIOU: 0.784640), Class: 0.872263, Obj: 0.021986, No Obj: 0.000118, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.256388, iou_loss = 0.016723, total_loss = 0.273112
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000049, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.007589, iou_loss = 0.000000, total_loss = 0.007589
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (248).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1243).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (105).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1175).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1748).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.830840, GIOU: 0.828015), Class: 0.999924, Obj: 0.163861, No Obj: 0.000785, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.200055, iou_loss = 0.061943, total_loss = 0.261998
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000004, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images (1).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (378).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images (14).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (321).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.676302, GIOU: 0.676302), Class: 0.999999, Obj: 0.361321, No Obj: 0.001043, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.169003, iou_loss = 0.051222, total_loss = 0.220225
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000056, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.017658, iou_loss = 0.000000, total_loss = 0.017658
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1659).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (125).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (278).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1176).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000113, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.001968, iou_loss = 0.000000, total_loss = 0.001968
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000003, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (52).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6049).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000086, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000207, iou_loss = 0.000000, total_loss = 0.000207
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (57).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.853208, GIOU: 0.846944), Class: 0.987571, Obj: 0.106267, No Obj: 0.000098, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.200270, iou_loss = 0.017526, total_loss = 0.217796
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6054).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1240).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.739221, GIOU: 0.739221), Class: 0.999327, Obj: 0.853910, No Obj: 0.000536, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.007421, iou_loss = 0.028847, total_loss = 0.036268
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (276).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (248).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000033, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.004099, iou_loss = 0.000000, total_loss = 0.004099
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1174).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (58).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (3991).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000117, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.007799, iou_loss = 0.000000, total_loss = 0.007799
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.687938, GIOU: 0.682930), Class: 0.982133, Obj: 0.072658, No Obj: 0.000043, .5R: 1.000000, .75R: 0.000000, count: 3, class_loss = 0.651232, iou_loss = 0.139931, total_loss = 0.791163
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.095.txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.919521, GIOU: 0.918596), Class: 0.999992, Obj: 0.894827, No Obj: 0.000888, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.005626, iou_loss = 0.015321, total_loss = 0.020948
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000011, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000311, iou_loss = 0.000000, total_loss = 0.000311
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (265).txt
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.791553, GIOU: 0.781079), Class: 0.999774, Obj: 0.227193, No Obj: 0.001970, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.424784, iou_loss = 0.072068, total_loss = 0.496852
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000011, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000167, iou_loss = 0.000000, total_loss = 0.000167
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000249, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.026836, iou_loss = 0.000000, total_loss = 0.026836
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000003, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000165, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.021066, iou_loss = 0.000000, total_loss = 0.021066
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.773706, GIOU: 0.759277), Class: 0.997537, Obj: 0.128110, No Obj: 0.000764, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.420661, iou_loss = 0.182444, total_loss = 0.603105
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000025, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.003920, iou_loss = 0.000000, total_loss = 0.003920
#
#  5240: 0.135913, 0.172332 avg loss, 0.000010 rate, 0.864413 seconds, 335360 images, 14508.822075 hours left
# Resizing, random_coef = 1.40
#
#  512 x 512
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.325.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (168).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (52).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192832.336.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6047).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192831.856.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (279).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (388).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6053).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1187).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1248).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1669).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (24).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6296).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1231).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (224).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (217).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6019).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (6068).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (264).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F-16_V1 (3788).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (171).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/images - 2020-06-02T192831.919.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (105).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1313).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B02 (257).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/F16_V22 (1289).txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/darknet/YOLO_Custom/images/B-02-V1 (226).txt
# ^C

# %%
confthres=0.2
nmsthres=0.1
path="./"
def get_labels(label_dir):
    return open(label_dir).read().split('\n')
      
def get_colors(LABELS):
    # initialize a list of colors to represent each possible class label
    np.random.seed(42)
    COLORS = np.random.randint(0, 255, size=(len(LABELS), 3),dtype="uint8")
    return COLORS

def get_weights(weights_path):
    # derive the paths to the YOLO weights and model configuration
    weightsPath = os.path.sep.join([yolo_path, weights_path])
    return weightsPath

def get_config(config_path):
    configPath = os.path.sep.join([yolo_path, config_path])
    return configPath

def load_model(configpath,weightspath):
    # load our YOLO object detector trained on COCO dataset (80 classes)
    print("[INFO] loading YOLO from disk...")
    net = cv2.dnn.readNetFromDarknet(configpath, weightspath)
    return net

# %%
def get_predection(image,net,LABELS,COLORS):
    (H, W) = image.shape[:2]

    # determine only the *output* layer names that we need from YOLO
    ln = net.getLayerNames()
    ln = [ln[i[0] - 1] for i in net.getUnconnectedOutLayers()]

    # construct a blob from the input image and then perform a forward
    # pass of the YOLO object detector, giving us our bounding boxes and
    # associated probabilities
    blob = cv2.dnn.blobFromImage(image, 1 / 255.0, (416, 416),
                                 swapRB=True, crop=False)
    net.setInput(blob)
    start = time.time()
    layerOutputs = net.forward(ln)
    #print(layerOutputs[0])
    end = time.time()

    # show timing information on YOLO
    #print("[INFO] YOLO took {:.6f} seconds".format(end - start))

    # initialize our lists of detected bounding boxes, confidences, and
    # class IDs, respectively
    boxes = []
    confidences = []
    classIDs = []
    num_class_0 = 0
    num_class_1 = 0

    # loop over each of the layer outputs
    for output in layerOutputs:
        # loop over each of the detections
        for detection in output:
            # extract the class ID and confidence (i.e., probability) of
            # the current object detection
            scores = detection[5:]
            #print(detection)
            classID = np.argmax(scores)
            # print(classID)
            confidence = scores[classID]

            # filter out weak predictions by ensuring the detected
            # probability is greater than the minimum probability
            if confidence > confthres:
                # scale the bounding box coordinates back relative to the
                # size of the image, keeping in mind that YOLO actually
                # returns the center (x, y)-coordinates of the bounding
                # box followed by the boxes' width and height
                box = detection[0:4] * np.array([W, H, W, H])
                (centerX, centerY, width, height) = box.astype("int")

                # use the center (x, y)-coordinates to derive the top and
                # and left corner of the bounding box
                x = int(centerX - (width / 2))
                y = int(centerY - (height / 2))

                # update our list of bounding box coordinates, confidences,
                # and class IDs
                boxes.append([x, y, int(width), int(height)])
                confidences.append(float(confidence))
                classIDs.append(classID)
                if(classID==0):
                  num_class_0 +=1
                elif(classID==1):
                  num_class_1 +=1  

    # apply non-maxima suppression to suppress weak, overlapping bounding
    # boxes
    idxs = cv2.dnn.NMSBoxes(boxes, confidences, confthres,
                            nmsthres)
    if(num_class_0>0 or num_class_1>0):
        index= num_class_0/(num_class_0+num_class_1)
    else:
      index=-1  
    #print(index,)    
    # ensure at least one detection exists
    if len(idxs) > 0:
        # loop over the indexes we are keeping
        for i in idxs.flatten():
            # extract the bounding box coordinates
            (x, y) = (boxes[i][0], boxes[i][1])
            (w, h) = (boxes[i][2], boxes[i][3])
            confidence = confidences[i]

            # draw a bounding box rectangle and label on the image
            color = [int(c) for c in COLORS[classIDs[i]]]
            cv2.rectangle(image, (x, y), (x + w, y + h), color, 2)
            text = "{}".format(LABELS[classIDs[i]])
            #print(boxes)
            #print(classIDs)      
            #cv2.putText(image, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX,0.5, color=(69, 60, 90), thickness=2)
            cv2.rectangle(image, (x, y-5), (x+62, y-15), color, cv2.FILLED)
            cv2.putText(image, text + " Confidence: " + str(round(confidence, 2)), (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX,0.5, (0,0,0), 1)
            #cv2.putText(frame, label + " " + str(round(confidence, 2)), (x, y + 30), font, 3, color, 3)
        '''    if(index!=-1 and index<.50):
                cv2.rectangle(image, (40, 46), (220, 16), (0,0,255), cv2.FILLED)
                cv2.putText(image,'Mask Adaptivity: POOR',(40,40),cv2.FONT_HERSHEY_SIMPLEX,0.5, (0,255,255), 1)
            elif(index>=.50 and index<.70):
                cv2.rectangle(image, (40, 46), (255, 16), (0, 165, 255), cv2.FILLED)
                cv2.putText(image,'Mask Adaptivity: MODERATE',(40,40),cv2.FONT_HERSHEY_SIMPLEX,0.5, (0,0,0), 1)  
            elif(index>=0.70):
                cv2.rectangle(image, (40, 46), (220, 16), (42,236,42), cv2.FILLED)
                cv2.putText(image,'Mask Adaptivity: HIGH',(40,40),cv2.FONT_HERSHEY_SIMPLEX,0.5, (0,0,0), 1)    '''  
    return image

# %%
# Method to predict  Image
def predict_image(img_path):
    image = cv2.imread(img_path)
    nets=load_model(CFG,Weights)
    #Colors=get_colors(Lables)
    Colors=[(42,236,42),(0,0,255)]
    res=get_predection(image,nets,Lables,Colors)
    # image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    # show the output image
    cv2_imshow(res)
    cv2.waitKey()

# %%
# Method to predict Video
def predict_video(input_path,output_path):
    vid = cv2.VideoCapture(input_path)
    op=output_path
    nets=load_model(CFG,Weights)
    Colors=[(42,236,42),(0,0,255)]
    height, width = None, None
    writer = None
    print('[Info] processing Video (It may take several minutes to Run)..')
    while True:
        grabbed, frame = vid.read()
		    # Checking if the complete video is read
        if not grabbed:
		        break
        if width is None or height is None:
		        height, width = frame.shape[:2]
        frame=get_predection(frame,nets,Lables,Colors)
        if writer is None:
          fourcc = cv2.VideoWriter_fourcc(*"mp4v")
          writer = cv2.VideoWriter(op, fourcc, 27,(frame.shape[1], frame.shape[0]), True)
        writer.write(frame)
    print ("[INFO] Cleaning up...")
    writer.release()
    vid.release()
    print ("[INFO] Prediction Completed.")

# %%
# This will not work  in colab, as colab can't access local hardware
import time
def predict_web_cam():
    #stream = cv2.VideoCapture(0)
    sess = K.get_session()
    while True:
        # Capture frame-by-frame
        grabbed, frame = stream.read()
        if not grabbed:
            break
        # Run detection
        start = time.time()
        image = Image.fromarray(frame)
        output_image =  get_predection(image,nets,Lables,Colors)
        end = time.time()
        print("Inference time: {:.2f}s".format(end - start))
        # Display the resulting frame
        cv2.imshow('Web Cam',np.asarray(output_image))
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    stream.release()    
    cv2.destroyAllWindows()

# %%
# Set the pah for test config file, label directory and weights
CFG='/content/darknet/YOLO_Custom/yolov3-tiny_obj_test.cfg'   
label_dir='/content/darknet/YOLO_Custom/obj.names'
#cfgpath=test_config_path
Weights='/content/darknet/yolov3-tiny_obj_train_5000.weights'
Lables=get_labels(label_dir)

# %%
from google.colab.patches import cv2_imshow
img_path='/content/darknet/YOLO_Custom/images/F16_V22 (1182).jpg' 
predict_image(img_path)

# %%
input_path='/content/B-2s Take Off From RAF Fairford - 15th June 2014.mp4'
output_path='/content/B-2s Take Off From RAF Fairford - 15th June 2014-d.mp4'
predict_video(input_path,output_path)
# Out:
# [INFO] loading YOLO from disk...
# [Info] processing Video (It may take several minutes to Run)..

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
